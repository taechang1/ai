# %% [markdown]
# <a href="https://colab.research.google.com/github/taechang1/ai/blob/master/7%ED%8C%90%EB%8B%A4%EC%8A%A4_%EC%98%88%EC%A0%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%ED%94%84%EB%A0%88%EC%9E%842.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 데이터 프레임 2차원

# %%
import pandas as pd

# %%
list1=list([['한빛','남자','20','180'],
                    ['한결','남자','21','177'],
                    ['한라','여자','20','160']])
col_names=['이름','성별','나이','키']
df1=pd.DataFrame(list1,columns=col_names)
df1

df2=pd.DataFrame(list1,index=['1반','2반','3반'], columns=col_names)
df2
df2.index
df2.values
# Out:
# array([['한빛', '남자', '20', '180'],
#        ['한결', '남자', '21', '177'],
#        ['한라', '여자', '20', '160']], dtype=object)

# %%
dict1={'이름':{0:'한빛',1:'한결',2:'한라'},
       '성별':{0:'남자',1:'남자',2:'여자'},
       '나이':{0:'20',1:'21',2:'20'},
       '키':{0:'180',1:'177',2:'160'}}
df2= pd.DataFrame(dict1)
df2
# Out:
#    이름  성별  나이    키
# 0  한빛  남자  20  180
# 1  한결  남자  21  177
# 2  한라  여자  20  160

# %%
#고고림까지 딕셔너리로 만들어 데이터프레임 생성하기
dic2={'이름':{0:'허준호',1:'이가원',2:'배규민',3:'고고림'},
      '성별':{0:'남자',1:'남자',2:'남자',3:'남자'},
      '나이':{0:'30',1:'24',2:'23',3:'21'},
      '키':{0:'183',1:'162',2:'179',3:'182'}
      }
df3=pd.DataFrame(dic2)
df3
df3.to_csv('df3.csv',header=True,index=False,encoding='cp949')

# %%
# 외부 iris.csv 파일 불러오기

# 방법1) 다운 받아서 코랩에 올려 주기

# 파일 업로드하기
#  from google.colab  import files
#  f = files.upload()
# iris_df  = pd.read_csv( 'iris.csv', sep = ',' , encoding='cp949'   )
# iris_df

# 방법2)  다운 받을 url 주소를 써주면 코랩에서 찾아서 올려 줌
iris_url = ' https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'      # Raw의 주소를 써 주세요.
iris_df  = pd.read_csv(  iris_url,  sep = ',' , encoding='cp949'   )
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd

# %%
#데이터 프레임 만들기
#list를 이용해서 만들기
list1 = [ [ 'KFC',  1000, 4.5],
             [ 'McDonald',  2000, 3.9],
             [ 'SchoolFood',  2500, 4.2],
          ]

col_names = [ 'food', 'price', 'rating' ]
df1 = pd.DataFrame( list1, col_names )
#딕셔너리를 이용해서 만들기
dic1={'food':{0:'KFC',1:'McDonald',2:'Scoolfood'},
      'price':{0:1000,1:2000,2:2500},
      'rating':{0:4.5,1:3.9,2:4.2},
      }

df2=pd.DataFrame(dic1)
df2
df2[['food','rating']]
df2['food']  # [   열이름 ]  결과를 시리즈로 보기
df2[['food']] # [ [ 열이름 ]]  결과를 데이터프레임 보기
df2.rename(columns={'food':'foods'})
df2
# Out:
#         food  price  rating
# 0        KFC   1000     4.5
# 1   McDonald   2000     3.9
# 2  Scoolfood   2500     4.2

# %%
data = [
    ["037730", "3R", 1510, 7.36],
    ["036360", "3SOFT", 1790, 1.65],
    ["005760", "ACTS", 1185, 1.28],
]
columns = ["종목코드", "종목명", "현재가", "등락률"]
df = pd.DataFrame(data=data, columns=columns)
df.set_index('종목코드', inplace=True)
df
#1.현재가가 1500이상인 값만
df[df['현재가']>=1500]
#2.현재가가1500원 이상이면서 1700원 미만인 값
cond=(df['현재가']>=1500)&(df['현재가']<1700)
df[cond]
#3.목표가 컬럼 추가
df['목표가']=df['현재가']*0.01
df
#4 행을 추가
df.loc['066570']=['LG전자',60000,3.84,60000*0.01]
df

df.loc['037730'] # 03770 인덱스 행의 정보를 보여준다

#5 컬럼명 변경(columns속성)
df5= pd.DataFrame(data=[[1,2,3],[4,5,6]],columns=["A","B","C"])
df5
#컬럼명을 'a','b','c'로 변경
df5.columns=['a','b','c']
df5
df5.rename(columns={'a':'가','b':'나','c':'다'},inplace=True)
df5
#7
import numpy as np
data={"카카오":[np.nan,221,35],"NAVER":[52,47,3]}
index=[2019,2020,2021]
df7=pd.DataFrame(data=data,index=index)
df7
df7.index.dtype
print(df7.columns.name,'~')
df7.index.name='year'#
df7.columns.name='company'
print(df7.index.name)
print(df7.columns.name)
#8
data={"카카오":[np.nan,221,35],"NAVER":[52,47,3]}
index=[2019,2020,2021]
df8=pd.DataFrame(data=data,index=index)
df8

#9데이터 프레임 drop'카카오'와'네이버'컬럼을 삭제
df8.drop('카카오',axis=1)
df8.drop('NAVER',axis=1)
df8.drop(['카카오','NAVER'],axis=1)
# 10
data = [
    [1, 2, 3],
    [np.nan, 5, 6],
    [7, np.nan, 9],
    [10, 11, np.nan]
]
df10 = pd.DataFrame(data)
df10
# np.nan 값이 있는 모든 행을 제거
df10.dropna()

# 11
data = [
    [1, 1, np.nan],
    [10, np.nan, 10],
    [2, 3, 4]
]
columns = ['col0', 'col1', 'col2']
df11 = pd.DataFrame(data, columns=columns)
df11
# 문제  col2 컬럼의 값에 NaN이 포함된 행만 제거
df11.dropna( subset = 'col2' )
# 12   NaN 값을 0으로 채우기
df12 = df11.fillna( 0 )
# 13 replace  0을 100으로 변경
df12.replace( 0, 100  )

# 14
data = [
    {"cd":"A060310", "nm":"3S", "open":2920, "close":2800},
    {"cd":"A095570", "nm":"AJ네트웍스", "open":1920, "close":1900},
    {"cd":"A006840", "nm":"AK홀딩스", "open":2020, "close":2010},
    {"cd":"A054620", "nm":"APS홀딩스", "open":3120, "close":3200}
]
df14 = pd.DataFrame(data=data)
df14 = df14.set_index('cd')
df14
# 종가(close)가 시가(open)보다 큰 데이터만 가져오기
df14.query( 'open  <  close '   )
# 15  종가(close)가 3,000원 이상인 종목만 출력
df14.query( 'close >= 3000' )
# 16  시가(open)가 2,000원 이상이고 종가(close)가 시가(open)이상인 종목
df14.query( 'open >=2000 and close >= open')
# 17.  종목명(nm)이 'A'로 시작하는 종목만 ??
# cond=df14[ 'nm'].str[ :1 ]
df14.query(     "nm.str.startswith('A')"   )
# 18. 종목명에 '홀딩스'가 포함된 종목만
df14.query( "nm.str.contains('홀딩스')" )
# 19.
data = {
    "PER": [6.42, 17.63, 21.09, 13.93],
    "PBR": [1.10, 1.49, 2.06, 1.88],
    "DPS": [1416, 1716, 2994, 1755]
}
index = ["2019/12", "2020/12", "2021/12", "2022/12(E)"]
df19 = pd.DataFrame(data=data, index=index)
# df19[ ['PER', 'PBR'] ]
#  20 PER'과 'PBR' 컬럼을 선택
df19.filter( items=[  'PER', 'PBR' ] , axis=1 )
# 21 filter 메서드를 사용해서 예상치인 '2022/12(E)'를 제외한 나머지 로우 데이터를 선택
df19.filter(  regex='12$', axis=0  )
# 22  "2022"년 데이터만 선택
df19.filter(  like='2022', axis = 0 )
# Out:
# None ~
# year
# company
#               PER   PBR   DPS
# 2022/12(E)  13.93  1.88  1755

# %%
from datetime import datetime
import numpy as np
import pandas as np

# %%
columns = ['open', 'high', 'low', 'close']
index = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

#df1 = pd.DataFrame(data=np.arange(0, 10).reshape(5,2), index=index, columns=['open', 'high'])
#df2 = pd.DataFrame(data=np.arange(10,20).reshape(5,2), index=index, columns=['low', 'close'])
#DataFrame.concat

#다음 df1, df2 데이터프레임을 위/아래로 연결하세요. concat 메서드에서 join='outer'를 사용하세요.

index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7)
]

index2 = [
    datetime(2022, 9, 6),
    datetime(2022, 9, 5)
]
#df1 = pd.DataFrame(np.arange(0, 6).reshape(2,3), index=index1, columns=['open', 'high', 'low'])
#df2 = pd.DataFrame(np.arange(6,12).reshape(2,3), index=index2, columns=['high', 'low', 'close'])
#6
s1=pd.Series(['a','b'])
s2=pd.Series(['c','d'])
pd.concat([s1,s2])

#7
pd.concat([s1,s2],axis=1)
#8
#df1=pd.DataFrame(np.arange(0,4))
#9
data=[
    ["2차전지(생산)", "SK이노베이션", 10.19, 1.29],
    ["해운", "팬오션", 21.23, 0.95],
    ["시스템반도체", "티엘아이", 35.97, 1.12],
    ["해운", "HMM", 21.52, 3.20],
    ["시스템반도체", "아이에이", 37.32, 3.55],
    ["2차전지(생산)", "LG화학", 83.06, 3.75]
    ]

columns = ["테마", "종목명", "PER", "PBR"]
df9= pd.DataFrame(data=data, columns=columns)
df9.groupby(by="테마").mean()
df9.groupby(by="테마").max()
df9.groupby(by="테마").min()
df9.groupby(by="테마").size()
#13
gb1=df9.groupby(by="테마")
gb1.get_group('2차전지(생산)')
df9.groupby(by="테마").mean()[['PER']]
#14
df9_g=df9.groupby(by="테마").mean()
df9_g.loc[['시스템반도체']]
#15 agg max함수
df9.groupby(by="테마").agg(max)
#16
df9.groupby(by="테마").agg({'PER':max,'PBR':min})
#17
for name,group in df9.groupby('테마'):
 print(name)
 print(group)
 #18
 df9.groupby(by="테마")[['PER','PBR']].agg([np.mean,np.std])
 #19
 df9.groupby(by='테마')['종목명'].nunique()
# Out:
# 2차전지(생산)
#          테마      종목명    PER   PBR
# 0  2차전지(생산)  SK이노베이션  10.19  1.29
# 5  2차전지(생산)     LG화학  83.06  3.75
# 시스템반도체
#        테마   종목명    PER   PBR
# 2  시스템반도체  티엘아이  35.97  1.12
# 4  시스템반도체  아이에이  37.32  3.55
# 해운
#    테마  종목명    PER   PBR
# 1  해운  팬오션  21.23  0.95
# 3  해운  HMM  21.52  3.20
# <ipython-input-52-6f270542417f>:48: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(by="테마").mean()
# <ipython-input-52-6f270542417f>:55: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(by="테마").mean()[['PER']]
# <ipython-input-52-6f270542417f>:57: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9_g=df9.groupby(by="테마").mean()

# %% [markdown]
# group by문제 추가

# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset( 'titanic' )
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# 컬럼(columns) 설명
#
# survivied: 생존여부 (1: 생존, 0: 사망)
#
# pclass: 좌석 등급 (1등급, 2등급, 3등급)
#
# sex: 성별
#
# age: 나이
#
# sibsp: 형제 + 배우자 수
#
# parch: 부모 + 자녀 수
#
# fare: 좌석 요금
#
# embarked: 탑승 항구 (S, C, Q)
#
# class: pclass와 동일
#
# who: 남자(man), 여자(woman), 아이(child)
#
# adult_male: 성인 남자 여부
#
# deck: 데크 번호 (알파벳 + 숫자 혼용)
#
# embark_town: 탑승 항구 이름
#
# alive: 생존여부 (yes, no)
#
# alone: 혼자 탑승 여부

# %%
df=sns.load_dataset('titanic')
df.head()
df['who'].value_counts()

# 사용자 함수 정의
def transform_who(x) :
    if x == 'man' :
      return '남자'
    elif x== 'woman' :
      return '여자'
    else:
      return '아이'

df['who'].apply(transform_who) # 사용자가 정의한 함수를 호출해주기 apply( 사용자 함수명)
df['who'].apply(transform_who).value_counts()

# 좌석 요금: fare
# 나이 : age
# 구하려는 값은 fare /age

def tr_fare_age(x):
  return x['fare'] / x['age']
df.apply(tr_fare_age,axis=1)
df.head() # 7.25 /22.0 = 0.329

#  문제타이타닉 호의 생존자와 사망자를 성별 기준으로 그룹핑하여 평균을 살펴보겠습니다.

df.groupby(by='sex').mean()

# a문제 성별 ,좌석등급(pclass) 별 통꼐
df.groupby(['sex','pclass']).mean()
df.groupby(['pclass','sex']).mean()

# 문제 성별(Sex), 좌석등급(pclass 별 통계 평균구하기 survived 열만 보기)
df.groupby(['sex','pclass']).mean()[['survived']]
df.groupby(['pclass','sex'])[['survived']].mean()

# 출력의 모습 바꾸기
df.groupby(['sex','pclass'])[['survived']].mean().reset_index()
#생존율 평균 구하기
df.groupby(['sex', 'pclass'])[['survived', 'age']].agg(['mean', 'sum'])
# Out:
# <ipython-input-61-c4feb3436d4d>:28: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by='sex').mean()
# <ipython-input-61-c4feb3436d4d>:31: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex','pclass']).mean()
# <ipython-input-61-c4feb3436d4d>:32: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['pclass','sex']).mean()
# <ipython-input-61-c4feb3436d4d>:35: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex','pclass']).mean()[['survived']]
#                survived            age
#                    mean sum       mean      sum
# sex    pclass
# female 1       0.968085  91  34.611765  2942.00
#        2       0.921053  70  28.722973  2125.50
#        3       0.500000  72  21.750000  2218.50
# male   1       0.368852  45  41.281386  4169.42
#        2       0.157407  17  30.740707  3043.33
#        3       0.135447  47  26.507589  6706.42

# %% [markdown]
# # **데이터 프레임 문제4**

# %%
import pandas as pd

data = [
    ['Multiples', 'PER', 21.09, 13.55],
    ['Multiples', 'PBR', 2.06, 1.80],
    ['Dividends', 'DPS', 2944, 1444],
    ['Dividends', '배당성향', 78, 25]
]
columns = ['Category', 'Factor', 2020, 2021]
df = pd.DataFrame(data, columns=columns)
df

#2 멀티 인덱스
df.set_index(['Category','Factor'])
df

# #3
# tuples = [
#     ('Multiples', 'PER'),
#     ('Multiples', 'PBR'),
#     ('Dividends', 'DPS'),
#     ('Dividends', '배당성향')
# ]
# index=pd.MultiIndex.from_tuples(tuples,names=['Category','Factor'])
# df
# #4
# arrays = [
#     ['Mutiples', 'Multiples', 'Dividends', 'Dividends'],
#     ['PER', 'PBR', 'DPS', '배당성향']
# ]
# index=pd.MultiIndex.from_arrays(arrays,names=['Category','Factor'])
# df
# Out:
#     Category Factor     2020     2021
# 0  Multiples    PER    21.09    13.55
# 1  Multiples    PBR     2.06     1.80
# 2  Dividends    DPS  2944.00  1444.00
# 3  Dividends   배당성향    78.00    25.00

# %%
#5
import pandas as pd

tuples = [
    ('Multiples', 'PER'),
    ('Multiples', 'PBR'),
    ('Dividends', 'DPS'),
    ('Dividends', '배당성향')
]


data = [
    [21.09, 13.55],
    [2.06, 1.80],
    [2944, 1444],
    [78, 25]
]

columns = [2020, 2021]
df

# #6
# df.loc['Multiples']

# #7
# df.loc[('Multiples','PER')]
# #8
# df.iloc[ 2]
# #9
# df.loc[('Multiples','PER'),2020]
# #10
# df.sort_index()
# Out:
#     Category Factor     2020     2021
# 0  Multiples    PER    21.09    13.55
# 1  Multiples    PBR     2.06     1.80
# 2  Dividends    DPS  2944.00  1444.00
# 3  Dividends   배당성향    78.00    25.00

# %% [markdown]
# ## 5데이터프레임 응용문제1- 붓꽃 데이터

# %%
iris_url='https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris_df=pd.read_csv(iris_url,sep=',',encoding='cp949')
iris_df.value_counts
# Out:
# <bound method DataFrame.value_counts of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>
